# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()

client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


lz_uri = 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'


spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id,client_secret=client_secret))
results = spotify.artist_top_tracks(lz_uri)

# %%
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5MLBEmgDNIltSfxvXesq9s'},
#     'href': 'https://api.spotify.com/v1/albums/5MLBEmgDNIltSfxvXesq9s',
#     'id': '5MLBEmgDNIltSfxvXesq9s',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273294ea58a8ac4ae598c46d0b0',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02294ea58a8ac4ae598c46d0b0',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851294ea58a8ac4ae598c46d0b0',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'El Fenomeno',
#     'release_date': '2008-12-08',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:5MLBEmgDNIltSfxvXesq9s'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 214120,
#    'explicit': False,
#    'external_ids': {'isrc': 'US3B90800016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1pLCpA1RN8avJxSD3ZCwhj'},
#    'href': 'https://api.spotify.com/v1/tracks/1pLCpA1RN8avJxSD3ZCwhj',
#    'id': '1pLCpA1RN8avJxSD3ZCwhj',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Pa' Que La Pases Bien",
#    'popularity': 80,
#    'preview_url': None,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:1pLCpA1RN8avJxSD3ZCwhj'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/12yPsAPzZ5584HxpItKBUn'},
#     'href': 'https://api.spotify.com/v1/albums/12yPsAPzZ5584HxpItKBUn',
#     'id': '12yPsAPzZ5584HxpItKBUn',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739bf23abed0a1e730a90d3490',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e029bf23abed0a1e730a90d3490',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048519bf23abed0a1e730a90d3490',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#     'release_date': '2016-09-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:12yPsAPzZ5584HxpItKBUn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2T1aUibqR2QC2sINIDQOAK'},
#      'href': 'https://api.spotify.com/v1/artists/2T1aUibqR2QC2sINIDQOAK',
#      'id': '2T1aUibqR2QC2sINIDQOAK',
#      'name': 'Mambo Kingz',
#      'type': 'artist',
#      'uri': 'spotify:artist:2T1aUibqR2QC2sINIDQOAK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/64aJYyrXljOodnUG6jvhRD'},
#      'href': 'https://api.spotify.com/v1/artists/64aJYyrXljOodnUG6jvhRD',
#      'id': '64aJYyrXljOodnUG6jvhRD',
#      'name': 'DJ Luian',
#      'type': 'artist',
#      'uri': 'spotify:artist:64aJYyrXljOodnUG6jvhRD'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'DJ',
#     'ZM',
#     'CG',
#     'TJ',
#     'VE',
#     'ET'],
#    'disc_number': 1,
#    'duration_ms': 264000,
#    'explicit': True,
#    'external_ids': {'isrc': 'TCACS1630643'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NSMQFKgjpQb0KkjMDYIK0'},
#    'href': 'https://api.spotify.com/v1/tracks/6NSMQFKgjpQb0KkjMDYIK0',
#    'id': '6NSMQFKgjpQb0KkjMDYIK0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)',
#    'popularity': 79,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6NSMQFKgjpQb0KkjMDYIK0'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2AvuFDqTlnxvYhyVaLU6NY'},
#     'href': 'https://api.spotify.com/v1/albums/2AvuFDqTlnxvYhyVaLU6NY',
#     'id': '2AvuFDqTlnxvYhyVaLU6NY',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27330326b23e30ae93d4d48165b',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0230326b23e30ae93d4d48165b',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485130326b23e30ae93d4d48165b',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Sr. Santos',
#     'release_date': '2022-12-01',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:2AvuFDqTlnxvYhyVaLU6NY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 255693,
#    'explicit': True,
#    'external_ids': {'isrc': 'QMDA72252608'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2mnXxnrX5vCGolNkaFvVeM'},
#    'href': 'https://api.spotify.com/v1/tracks/2mnXxnrX5vCGolNkaFvVeM',
#    'id': '2mnXxnrX5vCGolNkaFvVeM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'La Jumpa',
#    'popularity': 72,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2mnXxnrX5vCGolNkaFvVeM'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['CO', 'EC', 'PE', 'PR', 'US', 'VE'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/61bxUN2kedSEPjpvuLtSYe'},
#     'href': 'https://api.spotify.com/v1/albums/61bxUN2kedSEPjpvuLtSYe',
#     'id': '61bxUN2kedSEPjpvuLtSYe',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273172b684f5e6482f962b9a045',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02172b684f5e6482f962b9a045',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851172b684f5e6482f962b9a045',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Sentimiento, Elegancia y Maldad',
#     'release_date': '2013-11-19',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:61bxUN2kedSEPjpvuLtSYe'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#    'available_markets': ['CO', 'EC', 'PE', 'PR', 'US', 'VE'],
#    'disc_number': 1,
#    'duration_ms': 171333,
#    'explicit': False,
#    'external_ids': {'isrc': 'USB271300110'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Y0ZwhwMEQ7NIb5PeAp0YI'},
#    'href': 'https://api.spotify.com/v1/tracks/5Y0ZwhwMEQ7NIb5PeAp0YI',
#    'id': '5Y0ZwhwMEQ7NIb5PeAp0YI',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Hace Mucho Tiempo',
#    'popularity': 67,
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5Y0ZwhwMEQ7NIb5PeAp0YI'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1czm6WW5vuT5Cy1PrytBV9'},
#     'href': 'https://api.spotify.com/v1/albums/1czm6WW5vuT5Cy1PrytBV9',
#     'id': '1czm6WW5vuT5Cy1PrytBV9',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739e92bc926b08dd60341148a6',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e029e92bc926b08dd60341148a6',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048519e92bc926b08dd60341148a6',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Me Prefieres A Mi',
#     'release_date': '2012-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1czm6WW5vuT5Cy1PrytBV9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 195657,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZN882137995'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3GhmL9fuM8jwGcHCFbeo3v'},
#    'href': 'https://api.spotify.com/v1/tracks/3GhmL9fuM8jwGcHCFbeo3v',
#    'id': '3GhmL9fuM8jwGcHCFbeo3v',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Me Prefieres A Mi',
#    'popularity': 77,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3GhmL9fuM8jwGcHCFbeo3v'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#       'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#       'id': '7iK8PXO48WeuP03g8YR51W',
#       'name': 'Myke Towers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#       'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#       'id': '329e4yvIujISKGKz1BZZbO',
#       'name': 'Farruko',
#       'type': 'artist',
#       'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/75Y4sJ1vwZfEivbsKPzAx6'},
#     'href': 'https://api.spotify.com/v1/albums/75Y4sJ1vwZfEivbsKPzAx6',
#     'id': '75Y4sJ1vwZfEivbsKPzAx6',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2730e13eee4ec9f7ca9c603baf4',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e020e13eee4ec9f7ca9c603baf4',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048510e13eee4ec9f7ca9c603baf4',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Si Se da Remix',
#     'release_date': '2019-08-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:75Y4sJ1vwZfEivbsKPzAx6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#      'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#      'id': '7iK8PXO48WeuP03g8YR51W',
#      'name': 'Myke Towers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#      'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#      'id': '329e4yvIujISKGKz1BZZbO',
#      'name': 'Farruko',
#      'type': 'artist',
#      'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/77ziqFxp5gaInVrF2lj4ht'},
#      'href': 'https://api.spotify.com/v1/artists/77ziqFxp5gaInVrF2lj4ht',
#      'id': '77ziqFxp5gaInVrF2lj4ht',
#      'name': 'Sech',
#      'type': 'artist',
#      'uri': 'spotify:artist:77ziqFxp5gaInVrF2lj4ht'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pgDilWYDWLoOgGjf1iHNu'},
#      'href': 'https://api.spotify.com/v1/artists/1pgDilWYDWLoOgGjf1iHNu',
#      'id': '1pgDilWYDWLoOgGjf1iHNu',
#      'name': 'Zion',
#      'type': 'artist',
#      'uri': 'spotify:artist:1pgDilWYDWLoOgGjf1iHNu'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 332240,
#    'explicit': True,
#    'external_ids': {'isrc': 'QM6P41962776'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6K5BsR04ijf3FHNzjbaagD'},
#    'href': 'https://api.spotify.com/v1/tracks/6K5BsR04ijf3FHNzjbaagD',
#    'id': '6K5BsR04ijf3FHNzjbaagD',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Si Se Da - Remix',
#    'popularity': 76,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6K5BsR04ijf3FHNzjbaagD'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wYOpkTJZGByNEOjEnSmoW'},
#       'href': 'https://api.spotify.com/v1/artists/2wYOpkTJZGByNEOjEnSmoW',
#       'id': '2wYOpkTJZGByNEOjEnSmoW',
#       'name': 'Revol',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wYOpkTJZGByNEOjEnSmoW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#       'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#       'id': '1i8SpTcr7yvPOmcqrbnVXY',
#       'name': 'Ozuna',
#       'type': 'artist',
#       'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/00me4Ke1LsvMxt5kydlMyU'},
#       'href': 'https://api.spotify.com/v1/artists/00me4Ke1LsvMxt5kydlMyU',
#       'id': '00me4Ke1LsvMxt5kydlMyU',
#       'name': 'Cosculluela',
#       'type': 'artist',
#       'uri': 'spotify:artist:00me4Ke1LsvMxt5kydlMyU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3FAdUgqDYeqcvlpBTbGczq'},
#     'href': 'https://api.spotify.com/v1/albums/3FAdUgqDYeqcvlpBTbGczq',
#     'id': '3FAdUgqDYeqcvlpBTbGczq',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2734084b39ae3c80401165696a1',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e024084b39ae3c80401165696a1',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048514084b39ae3c80401165696a1',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Me Ama Me Odia',
#     'release_date': '2016-09-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3FAdUgqDYeqcvlpBTbGczq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wYOpkTJZGByNEOjEnSmoW'},
#      'href': 'https://api.spotify.com/v1/artists/2wYOpkTJZGByNEOjEnSmoW',
#      'id': '2wYOpkTJZGByNEOjEnSmoW',
#      'name': 'Revol',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wYOpkTJZGByNEOjEnSmoW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#      'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#      'id': '1i8SpTcr7yvPOmcqrbnVXY',
#      'name': 'Ozuna',
#      'type': 'artist',
#      'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/00me4Ke1LsvMxt5kydlMyU'},
#      'href': 'https://api.spotify.com/v1/artists/00me4Ke1LsvMxt5kydlMyU',
#      'id': '00me4Ke1LsvMxt5kydlMyU',
#      'name': 'Cosculluela',
#      'type': 'artist',
#      'uri': 'spotify:artist:00me4Ke1LsvMxt5kydlMyU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/00XhexlJEXQstHimpZN910'},
#      'href': 'https://api.spotify.com/v1/artists/00XhexlJEXQstHimpZN910',
#      'id': '00XhexlJEXQstHimpZN910',
#      'name': 'Brytiago',
#      'type': 'artist',
#      'uri': 'spotify:artist:00XhexlJEXQstHimpZN910'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 326936,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZS1Z1606748'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6TZXBJLTIOX6DM6hwCsKw2'},
#    'href': 'https://api.spotify.com/v1/tracks/6TZXBJLTIOX6DM6hwCsKw2',
#    'id': '6TZXBJLTIOX6DM6hwCsKw2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Me Ama Me Odia',
#    'popularity': 76,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6TZXBJLTIOX6DM6hwCsKw2'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7a0XAaPaK2aDSqa8p3QnC7'},
#       'href': 'https://api.spotify.com/v1/artists/7a0XAaPaK2aDSqa8p3QnC7',
#       'id': '7a0XAaPaK2aDSqa8p3QnC7',
#       'name': 'Beéle',
#       'type': 'artist',
#       'uri': 'spotify:artist:7a0XAaPaK2aDSqa8p3QnC7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5y4gn8YJaRqaN5JQLgCZ0n'},
#     'href': 'https://api.spotify.com/v1/albums/5y4gn8YJaRqaN5JQLgCZ0n',
#     'id': '5y4gn8YJaRqaN5JQLgCZ0n',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273e49198e11d6d0cb1a1bb204c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02e49198e11d6d0cb1a1bb204c',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851e49198e11d6d0cb1a1bb204c',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Por Vos',
#     'release_date': '2025-03-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5y4gn8YJaRqaN5JQLgCZ0n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7a0XAaPaK2aDSqa8p3QnC7'},
#      'href': 'https://api.spotify.com/v1/artists/7a0XAaPaK2aDSqa8p3QnC7',
#      'id': '7a0XAaPaK2aDSqa8p3QnC7',
#      'name': 'Beéle',
#      'type': 'artist',
#      'uri': 'spotify:artist:7a0XAaPaK2aDSqa8p3QnC7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 185394,
#    'explicit': True,
#    'external_ids': {'isrc': 'QM6MZ2523276'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6pXo0WoRNLSid8mbpmJ4Wz'},
#    'href': 'https://api.spotify.com/v1/tracks/6pXo0WoRNLSid8mbpmJ4Wz',
#    'id': '6pXo0WoRNLSid8mbpmJ4Wz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Por Vos',
#    'popularity': 76,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6pXo0WoRNLSid8mbpmJ4Wz'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#       'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#       'id': '4SsVbpTthjScTS7U2hmr1X',
#       'name': 'Arcángel',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/21TAcmAXy0OY0U7B9LlwlY'},
#     'href': 'https://api.spotify.com/v1/albums/21TAcmAXy0OY0U7B9LlwlY',
#     'id': '21TAcmAXy0OY0U7B9LlwlY',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735947e677a3370208d0ba491d',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e025947e677a3370208d0ba491d',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048515947e677a3370208d0ba491d',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Sentimiento, Elegancia y Más Maldad',
#     'release_date': '2023-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:21TAcmAXy0OY0U7B9LlwlY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#      'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#      'id': '6XkjpgcEsYab502Vr1bBeW',
#      'name': 'Grupo Frontera',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 224285,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMFMF2330232'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/32hCeeK3ayPux4UauNPsgA'},
#    'href': 'https://api.spotify.com/v1/tracks/32hCeeK3ayPux4UauNPsgA',
#    'id': '32hCeeK3ayPux4UauNPsgA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'ALV',
#    'popularity': 74,
#    'preview_url': None,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:32hCeeK3ayPux4UauNPsgA'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ixNZvQuuzCDxBsxO9zE6L'},
#       'href': 'https://api.spotify.com/v1/artists/4ixNZvQuuzCDxBsxO9zE6L',
#       'id': '4ixNZvQuuzCDxBsxO9zE6L',
#       'name': 'Gonzy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ixNZvQuuzCDxBsxO9zE6L'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4K4avZBw8VwDiTaukQ0snS'},
#     'href': 'https://api.spotify.com/v1/albums/4K4avZBw8VwDiTaukQ0snS',
#     'id': '4K4avZBw8VwDiTaukQ0snS',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2739b6b17f9c7fe03849d6d8a79',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e029b6b17f9c7fe03849d6d8a79',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d000048519b6b17f9c7fe03849d6d8a79',
#       'height': 64,
#       'width': 64}],
#     'is_playable': True,
#     'name': 'THE WORLD IS YOURS',
#     'release_date': '2024-10-11',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:4K4avZBw8VwDiTaukQ0snS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ixNZvQuuzCDxBsxO9zE6L'},
#      'href': 'https://api.spotify.com/v1/artists/4ixNZvQuuzCDxBsxO9zE6L',
#      'id': '4ixNZvQuuzCDxBsxO9zE6L',
#      'name': 'Gonzy',
#      'type': 'artist',
#      'uri': 'spotify:artist:4ixNZvQuuzCDxBsxO9zE6L'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2O8vbr4RYPpk6MRA4fio7u'},
#      'href': 'https://api.spotify.com/v1/artists/2O8vbr4RYPpk6MRA4fio7u',
#      'id': '2O8vbr4RYPpk6MRA4fio7u',
#      'name': 'SAIKO',
#      'type': 'artist',
#      'uri': 'spotify:artist:2O8vbr4RYPpk6MRA4fio7u'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SsVbpTthjScTS7U2hmr1X'},
#      'href': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X',
#      'id': '4SsVbpTthjScTS7U2hmr1X',
#      'name': 'Arcángel',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SsVbpTthjScTS7U2hmr1X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 208133,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZWGJ2400057'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5orb2qBX5ISKtsSy20v8SK'},
#    'href': 'https://api.spotify.com/v1/tracks/5orb2qBX5ISKtsSy20v8SK',
#    'id': '5orb2qBX5ISKtsSy20v8SK',
#    'is_local': False,
#    'is_playable': True,
#    'name': "X'CLUSIVO - REMIX",
#    'popularity': 67,
#    'preview_url': None,
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:5orb2qBX5ISKtsSy20v8SK'}]}

# %%
canciones=[]
popularidad=[]
duracion=[]


for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    canciones.append(track['name'])
    popularidad.append(track['popularity'])
    duracion.append(track['duration_ms']/(1000*60)%60)
# Out:
# track    : Pa' Que La Pases Bien
# track    : Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)
# track    : La Jumpa
# track    : Hace Mucho Tiempo
# track    : Me Prefieres A Mi
# track    : Si Se Da - Remix
# track    : Me Ama Me Odia
# track    : Por Vos
# track    : ALV
# track    : X'CLUSIVO - REMIX

# %%
popularidad
# Out:
# [80, 79, 72, 67, 77, 76, 76, 76, 74, 67]

# %%
df=pd.DataFrame()

df['Canciones']=pd.DataFrame(canciones)
df['Popularidad']=pd.DataFrame(popularidad)
df['Duracion']=pd.DataFrame(duracion)
df.index +=1

# %%
df
# Out:
#                                         Canciones  Popularidad  Duracion
# 1                           Pa' Que La Pases Bien           80  3.568667
# 2   Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)           79  4.400000
# 3                                        La Jumpa           72  4.261550
# 4                               Hace Mucho Tiempo           67  2.855550
# 5                               Me Prefieres A Mi           77  3.260950
# 6                                Si Se Da - Remix           76  5.537333
# 7                                  Me Ama Me Odia           76  5.448933
# 8                                         Por Vos           76  3.089900
# 9                                             ALV           74  3.738083
# 10                              X'CLUSIVO - REMIX           67  3.468883
